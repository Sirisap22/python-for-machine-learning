# %% [markdown]
# # How to Deploy Machine Learning Model
#
# หลังจากที่เราทำการ Training ตัว Machine Learning Model ของเราจนพอใจแล้ว
# เราก็พร้อมที่จะนำ Model ของเราไปใช้งานจริง โดยวิธีที่ง่ายที่สุดวิธีหนึ่งในในการใช้งาน Model ของเราคือ
# การสร้าง Web Service เพื่อเป็น API สำหรับให้ Developer ไปพัฒนาต่อเป็น Mobile App, Desktop App, Web Site
#
# ![](./images/overview.png)

# %% [markdown]
# # Example: Desicion Tree Classifier
#
# ![](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png)

# %% [markdown]
# ## Train Model

# %%
from sklearn.datasets import load_iris
from sklearn import tree
iris = load_iris()
X, y = iris.data, iris.target
model = tree.DecisionTreeClassifier()
model = model.fit(X, y)

# %% [markdown]
# ## Make Perdiction

# %%
sepal_length = 4.8
sepal_width = 3.1
petal_length = 1.5
petal_width = 0.3
unknown_iris = [sepal_length, sepal_width, petal_length, petal_width]

# %%
prediction = model.predict([unknown_iris])[0]

if prediction == 0:
    print('Iris-Setosa')
elif prediction == 1:
    print('Iris-Versicolour')
elif prediction == 2:
    print("Iris-Virginica")
# Out:
# Iris-Setosa

# %% [markdown]
# ## Export Model

# %%
import pickle
with open('iris_decision_tree_classifier.pkl', 'wb') as file:
    pickle.dump(model, file)
